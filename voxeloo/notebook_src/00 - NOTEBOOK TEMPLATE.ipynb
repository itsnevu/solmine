# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "py_src")
sys.path.insert(0, "../py_src")
sys.path.insert(0, "../../py_src")

from voxeloo.notebooks.imports import *
